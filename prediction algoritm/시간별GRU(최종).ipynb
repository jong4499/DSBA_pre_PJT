# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df0 = pd.read_csv('/content/sample12.csv', index_col=0, parse_dates=True)
df0
# Out:
#                      temp  year  month  day  hour  person  accum
# date
# 2021-01-01 00:00:00  -0.8  2021      1    1     0       0      0
# 2021-01-01 01:00:00  -1.8  2021      1    1     1       0      0
# 2021-01-01 02:00:00  -2.4  2021      1    1     2       1      1
# 2021-01-01 03:00:00  -2.9  2021      1    1     3       0      1
# 2021-01-01 04:00:00  -3.7  2021      1    1     4       0      1
# ...                   ...   ...    ...  ...   ...     ...    ...
# 2022-12-31 19:00:00   3.9  2022     12   31    19       0      7
# 2022-12-31 20:00:00   3.1  2022     12   31    20       0      7
# 2022-12-31 21:00:00   2.4  2022     12   31    21       0      7
# 2022-12-31 22:00:00   1.9  2022     12   31    22       0      7
# 2022-12-31 23:00:00   1.5  2022     12   31    23       1      8
#
# [17520 rows x 7 columns]

# %%
df0 = df0.drop(['year','day','hour','month','temp','person'], axis=1)

# %%
df0
# Out:
#                      accum
# date
# 2021-01-01 00:00:00      0
# 2021-01-01 01:00:00      0
# 2021-01-01 02:00:00      1
# 2021-01-01 03:00:00      1
# 2021-01-01 04:00:00      1
# ...                    ...
# 2022-12-31 19:00:00      7
# 2022-12-31 20:00:00      7
# 2022-12-31 21:00:00      7
# 2022-12-31 22:00:00      7
# 2022-12-31 23:00:00      8
#
# [17520 rows x 1 columns]

# %%
df0.reset_index(drop=False,inplace=True)
df0
# Out:
#                      date  accum
# 0     2021-01-01 00:00:00      0
# 1     2021-01-01 01:00:00      0
# 2     2021-01-01 02:00:00      1
# 3     2021-01-01 03:00:00      1
# 4     2021-01-01 04:00:00      1
# ...                   ...    ...
# 17515 2022-12-31 19:00:00      7
# 17516 2022-12-31 20:00:00      7
# 17517 2022-12-31 21:00:00      7
# 17518 2022-12-31 22:00:00      7
# 17519 2022-12-31 23:00:00      8
#
# [17520 rows x 2 columns]

# %%
stock_data = df0.groupby([pd.Grouper(key='date',freq='2h')]).max()

# %%
stock_data
# Out:
#                      accum
# date
# 2021-01-01 00:00:00      0
# 2021-01-01 02:00:00      1
# 2021-01-01 04:00:00      2
# 2021-01-01 06:00:00      3
# 2021-01-01 08:00:00      3
# ...                    ...
# 2022-12-31 14:00:00      5
# 2022-12-31 16:00:00      6
# 2022-12-31 18:00:00      7
# 2022-12-31 20:00:00      7
# 2022-12-31 22:00:00      8
#
# [8760 rows x 1 columns]

# %%
len(stock_data['accum'])
# Out:
# 8760

# %%
testdata2 = df0.groupby([pd.Grouper(key='date',freq='2h')]).max()

# %%
testdata2.reset_index(drop=False,inplace=True)
testdata2
# Out:
#                     date  accum
# 0    2021-01-01 00:00:00      0
# 1    2021-01-01 02:00:00      1
# 2    2021-01-01 04:00:00      2
# 3    2021-01-01 06:00:00      3
# 4    2021-01-01 08:00:00      3
# ...                  ...    ...
# 8755 2022-12-31 14:00:00      5
# 8756 2022-12-31 16:00:00      6
# 8757 2022-12-31 18:00:00      7
# 8758 2022-12-31 20:00:00      7
# 8759 2022-12-31 22:00:00      8
#
# [8760 rows x 2 columns]

# %%
original_open = stock_data['accum'].values
dates = pd.to_datetime(testdata2['date'])

# %%
cols = list(testdata2)[1:2]

stock_data = stock_data[cols].astype(float)

# %%
cols
# Out:
# ['accum']

# %%
from sklearn.preprocessing import StandardScaler

# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(stock_data)
stock_data_scaled = scaler.transform(stock_data)

# %%
n_train = int(0.9*stock_data_scaled.shape[0])
train_data_scaled = stock_data_scaled[0: n_train]
train_dates = dates[0: n_train]

test_data_scaled = stock_data_scaled[n_train:]
test_dates = dates[n_train:]

# %%
import numpy as np
# data reformatting for LSTM
pred_days = 1  # prediction period
seq_len = 14   # sequence length = past days for future prediction.
input_dim = 1  # input_dimension = ['Open', 'High', 'Low', 'Close', 'Volume']

trainX = []
trainY = []
testX = []
testY = []

for i in range(seq_len, n_train-pred_days +1):
    trainX.append(train_data_scaled[i - seq_len:i, 0:train_data_scaled.shape[1]])
    trainY.append(train_data_scaled[i + pred_days - 1:i + pred_days, 0])

for i in range(seq_len, len(test_data_scaled)-pred_days +1):
    testX.append(test_data_scaled[i - seq_len:i, 0:test_data_scaled.shape[1]])
    testY.append(test_data_scaled[i + pred_days - 1:i + pred_days, 0])

trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# GRU model
model = Sequential()
model.add(GRU(64, input_shape=(trainX.shape[1], trainX.shape[2]),
              return_sequences=True))
model.add(GRU(32, return_sequences=False))
model.add(Dense(trainY.shape[1]))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 14, 64)            12864
#
#  gru_1 (GRU)                 (None, 32)                9408
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 22305 (87.13 KB)
# Trainable params: 22305 (87.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# specify your learning rate
learning_rate = 0.01
# create an Adam optimizer with the specified learning rate
optimizer = Adam(learning_rate=learning_rate)
# compile your model using the custom optimizer
model.compile(optimizer=optimizer, loss='mse')

# %%
# Try to load weights
try:
    model.load_weights('./save_weights/gru_weights.h5')
    print("Loaded model weights from disk")
except:
    print("No weights found, training model from scratch")
    # Fit the model
    history = model.fit(trainX, trainY, epochs=50, batch_size=32,
                    validation_split=0.1, verbose=1)
    # Save model weights after training
    model.save_weights('/content/gru_weights.h5')
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.legend()
    plt.show()
# Out:
# No weights found, training model from scratch
# Epoch 1/50
# 222/222 [==============================] - 9s 21ms/step - loss: 0.2952 - val_loss: 0.1404
# Epoch 2/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0907 - val_loss: 0.1010
# Epoch 3/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0969 - val_loss: 0.0943
# Epoch 4/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0734 - val_loss: 0.0911
# Epoch 5/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0709 - val_loss: 0.0935
# Epoch 6/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0745 - val_loss: 0.0965
# Epoch 7/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0691 - val_loss: 0.0858
# Epoch 8/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0689 - val_loss: 0.0792
# Epoch 9/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0661 - val_loss: 0.0794
# Epoch 10/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0788 - val_loss: 0.2339
# Epoch 11/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.1790 - val_loss: 0.0988
# Epoch 12/50
# 222/222 [==============================] - 4s 20ms/step - loss: 0.1164 - val_loss: 0.1017
# Epoch 13/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0738 - val_loss: 0.1100
# Epoch 14/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0712 - val_loss: 0.0864
# Epoch 15/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0713 - val_loss: 0.1054
# Epoch 16/50
# 222/222 [==============================] - 3s 16ms/step - loss: 0.0746 - val_loss: 0.0841
# Epoch 17/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0724 - val_loss: 0.0853
# Epoch 18/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0677 - val_loss: 0.0738
# Epoch 19/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0689 - val_loss: 0.0962
# Epoch 20/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0680 - val_loss: 0.0748
# Epoch 21/50
# 222/222 [==============================] - 4s 19ms/step - loss: 0.0675 - val_loss: 0.0756
# Epoch 22/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.0662 - val_loss: 0.0760
# Epoch 23/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0657 - val_loss: 0.0785
# Epoch 24/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0681 - val_loss: 0.0827
# Epoch 25/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0645 - val_loss: 0.1028
# Epoch 26/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.0657 - val_loss: 0.0779
# Epoch 27/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.0666 - val_loss: 0.0781
# Epoch 28/50
# 222/222 [==============================] - 5s 22ms/step - loss: 0.0711 - val_loss: 0.0782
# Epoch 29/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0661 - val_loss: 0.0777
# Epoch 30/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0873 - val_loss: 0.1011
# Epoch 31/50
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0693 - val_loss: 0.1008
# Epoch 32/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0670 - val_loss: 0.0864
# Epoch 33/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0672 - val_loss: 0.0802
# Epoch 34/50
# 222/222 [==============================] - 5s 22ms/step - loss: 0.0667 - val_loss: 0.0815
# Epoch 35/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0686 - val_loss: 0.0881
# Epoch 36/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0670 - val_loss: 0.0852
# Epoch 37/50
# 222/222 [==============================] - 4s 20ms/step - loss: 0.0654 - val_loss: 0.0842
# Epoch 38/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.0650 - val_loss: 0.0720
# Epoch 39/50
# 222/222 [==============================] - 4s 16ms/step - loss: 0.0642 - val_loss: 0.0775
# Epoch 40/50
# 222/222 [==============================] - 4s 19ms/step - loss: 0.0658 - val_loss: 0.0809
# Epoch 41/50
# 222/222 [==============================] - 4s 20ms/step - loss: 0.0645 - val_loss: 0.0736
# Epoch 42/50
# 222/222 [==============================] - 4s 18ms/step - loss: 0.0651 - val_loss: 0.0780
# Epoch 43/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0638 - val_loss: 0.0779
# Epoch 44/50
# 222/222 [==============================] - 5s 22ms/step - loss: 0.0632 - val_loss: 0.0883
# Epoch 45/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0649 - val_loss: 0.0737
# Epoch 46/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0641 - val_loss: 0.0777
# Epoch 47/50
# 222/222 [==============================] - 5s 22ms/step - loss: 0.0690 - val_loss: 0.0897
# Epoch 48/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0654 - val_loss: 0.0980
# Epoch 49/50
# 222/222 [==============================] - 4s 17ms/step - loss: 0.0667 - val_loss: 0.0927
# Epoch 50/50
# 222/222 [==============================] - 5s 22ms/step - loss: 0.0673 - val_loss: 0.0750

# %%
# prediction
prediction = model.predict(testX)
print(prediction.shape, testY.shape)
# Out:
# 27/27 [==============================] - 1s 4ms/step
# (862, 1) (862, 1)

# %%
# prediction
prediction = model.predict(testX)
print(prediction.shape, testY.shape)

# generate array filled with means for prediction
mean_values_pred = np.repeat(scaler.mean_[np.newaxis, :], prediction.shape[0], axis=0)

# substitute predictions into the first column
mean_values_pred[:, 0] = np.squeeze(prediction)

# inverse transform
y_pred = scaler.inverse_transform(mean_values_pred)[:,0]
print(y_pred.shape)
# Out:
# 27/27 [==============================] - 0s 5ms/step
# (862, 1) (862, 1)
# (862,)

# %%
# generate array filled with means for testY
mean_values_testY = np.repeat(scaler.mean_[np.newaxis, :], testY.shape[0], axis=0)

# substitute testY into the first column
mean_values_testY[:, 0] = np.squeeze(testY)

# inverse transform
testY_original = scaler.inverse_transform(mean_values_testY)[:,0]
print(testY_original.shape)
# Out:
# (862,)

# %%
# plotting
plt.figure(figsize=(14, 5))

# %%
# plot original 'Open' prices
plt.plot(dates, original_open, color='green', label='Original Open Price')

# plot actual vs predicted
plt.plot(test_dates[seq_len:], testY_original, color='blue', label='Actual People')
plt.plot(test_dates[seq_len:], y_pred, color='red', linestyle='--', label='Predicted People')
plt.xlabel('Date')
plt.ylabel('accum_person')
plt.title('Original, Actual and Predicted People')
plt.legend()
plt.show()

# %%
# Calculate the start and end indices for the zoomed plot
zoom_start = len(test_dates) - 50
zoom_end = len(test_dates)

# Create the zoomed plot
plt.figure(figsize=(14, 5))

# Adjust the start index for the testY_original and y_pred arrays
adjusted_start = zoom_start - seq_len

plt.plot(test_dates[zoom_start:zoom_end],
         testY_original[adjusted_start:zoom_end - zoom_start + adjusted_start],
         color='blue',
         label='Actual People')

plt.plot(test_dates[zoom_start:zoom_end],
         y_pred[adjusted_start:zoom_end - zoom_start + adjusted_start ],
         color='red',
         linestyle='--',
         label='Predicted People')

plt.xlabel('Date')
plt.ylabel('Open People')
plt.title('Zoomed In Actual vs Predicted People')
plt.legend()
plt.show()

# %%
y_test = testY_original[adjusted_start:zoom_end - zoom_start + adjusted_start]

# %%
predpred = y_pred[adjusted_start:zoom_end - zoom_start + adjusted_start ]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predpred)
print(f"평균 제곱 오차 (MSE): {mse}")
# Out:
# 평균 제곱 오차 (MSE): 0.4341788997793848

# %%
# RMSE 계산
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.6589225294216193
